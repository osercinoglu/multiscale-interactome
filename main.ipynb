# %% [markdown]
# # Using the multiscale interactome

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from msi.msi import MSI
from diff_prof.diffusion_profiles import DiffusionProfiles
import multiprocessing
import numpy as np
import pickle
import networkx as nx

from tests.msi import test_msi
from tests.diff_prof import test_diffusion_profiles

# %% [markdown]
# # Construct the multiscale interactome

# %%
msi = MSI()
msi.load()

# %%
# Test against reference
test_msi()

# %% [markdown]
# # Calculate diffusion profiles

# %%
dp = DiffusionProfiles(alpha = 0.8595436247434408, max_iter = 1000, tol = 1e-06, weights = {'down_biological_function': 4.4863053901688685, 'indication': 3.541889556309463, 'biological_function': 6.583155399238509, 'up_biological_function': 2.09685000906964, 'protein': 4.396695660380823, 'drug': 3.2071696595616364}, num_cores = int(multiprocessing.cpu_count()/2) - 4, save_load_file_path = "results/")

# %%
dp.calculate_diffusion_profiles(msi)

# %%
dp.load_diffusion_profiles(msi.drugs_in_graph + msi.indications_in_graph)

# %%
# Diffusion profile for Rosuvastatin (DB01098)
dp.drug_or_indication2diffusion_profile["DB01098"]
# Out:
# array([6.88378645e-04, 3.78321317e-05, 2.92853909e-05, ...,
#        6.39679047e-06, 6.44090963e-06, 6.44090963e-06], shape=(29959,))

# %%
msi.idx2node
# Out:
# {0: 'DB12010',
#  1: '90',
#  2: 'DB01169',
#  3: '5371',
#  4: 'DB00459',
#  5: '6774',
#  6: 'DB06803',
#  7: 'DB09462',
#  8: '375',
#  9: 'DB01593',
#  10: '226',
#  11: 'DB02709',
#  12: '351',
#  13: 'DB06782',
#  14: 'DB00746',
#  15: '333',
#  16: 'DB01094',
#  17: '4547',
#  18: 'DB08827',
#  19: 'DB00619',
#  20: '1436',
#  21: 'DB01268',
#  22: 'DB06589',
#  23: 'DB00397',
#  24: '153',
#  25: 'DB00368',
#  26: 'DB00960',
#  27: 'DB00598',
#  28: 'DB00852',
#  29: 'DB00335',
#  30: 'DB08985',
#  31: 'DB00187',
#  32: 'DB04855',
#  33: 'DB01151',
#  34: 'DB00726',
#  35: 'DB00489',
#  36: 'DB09068',
#  37: 'DB01295',
#  38: 'DB13345',
#  39: 'clorprenaline',
#  40: 'DB00521',
#  41: 'DB00612',
#  42: 'DB01136',
#  43: 'DB01214',
#  44: 'DB00221',
#  45: 'DB00127',
#  46: 'DB11273',
#  47: 'DB00866',
#  48: 'DB00571',
#  49: 'DB00871',
#  50: 'DB08807',
#  51: 'DB00334',
#  52: 'DB06262',
#  53: 'DB01288',
#  54: 'DB01359',
#  55: 'DB05039',
#  56: 'DB01182',
#  57: 'DB01193',
#  58: 'DB00540',
#  59: 'DB01365',
#  60: 'DB01291',
#  61: 'DB09351',
#  62: 'DB01118',
#  63: 'DB00182',
#  64: 'DB00555',
#  65: 'DB00668',
#  66: 'DB00408',
#  67: 'DB01064',
#  68: 'DB01407',
#  69: 'DB01001',
#  70: 'DB00264',
#  71: 'DB00195',
#  72: 'DB08808',
#  73: 'DB00841',
#  74: 'DB00938',
#  75: 'DB08893',
#  76: 'DB00373',
#  77: 'DB00321',
#  78: 'DB00248',
#  79: 'DB01102',
#  80: 'DB06216',
#  81: 'DB01297',
#  82: 'DB00983',
#  83: 'DB04861',
#  84: 'DB04846',
#  85: 'DB00370',
#  86: 'DB01049',
#  87: 'DB01210',
#  88: 'DB01580',
#  89: 'DB01203',
#  90: 'carazolol',
#  91: 'DB09301',
#  92: '2668',
#  93: 'DB00661',
#  94: '775',
#  95: 'DB09229',
#  96: 'DB00653',
#  97: 'DB00825',
#  98: 'DB13500',
#  99: 'DB00568',
#  100: 'DB08872',
#  101: 'DB09089',
#  102: 'DB09230',
#  103: 'DB00230',
#  104: 'DB00270',
#  105: 'DB00622',
#  106: 'DB01023',
#  107: 'DB12278',
#  108: 'DB00996',
#  109: 'DB00308',
#  110: 'DB00898',
#  111: 'DB00381',
#  112: 'DB09090',
#  113: 'DB00343',
#  114: 'DB01115',
#  115: 'DB00401',
#  116: 'DB00393',
#  117: 'DB00421',
#  118: 'DB04920',
#  119: 'DB09235',
#  120: 'DB00201',
#  121: '3708',
#  122: 'DB00909',
#  123: '767',
#  124: 'DB03904',
#  125: '1499',
#  126: 'DB00071',
#  127: '5925',
#  128: 'DB00030',
#  129: '1026',
#  130: 'DB00129',
#  131: '10166',
#  132: 'DB06616',
#  133: '1017',
#  134: 'DB04272',
#  135: '9146',
#  136: 'DB01277',
#  137: '3486',
#  138: 'DB00523',
#  139: 'DB04866',
#  140: '1277',
#  141: 'DB00048',
#  142: 'DB00091',
#  143: '819',
#  144: '1445',
#  145: 'DB01254',
#  146: 'DB00047',
#  147: '3643',
#  148: 'DB01307',
#  149: 'DB09564',
#  150: 'DB01309',
#  151: 'DB01306',
#  152: 'DB00046',
#  153: '3480',
#  154: 'DB01179',
#  155: 'DB03754',
#  156: '1634',
#  157: 'DB00002',
#  158: '1956',
#  159: 'DB00072',
#  160: 'DB09559',
#  161: 'DB00317',
#  162: 'DB00281',
#  163: 'DB00530',
#  164: 'DB05294',
#  165: 'DB00279',
#  166: '5111',
#  167: 'DB00444',
#  168: '7155',
#  169: 'DB00380',
#  170: 'DB00970',
#  171: 'DB00773',
#  172: 'DB00694',
#  173: '1915',
#  174: 'DB08875',
#  175: '3791',
#  176: 'DB05578',
#  177: 'DB00398',
#  178: 'DB08901',
#  179: 'DB08896',
#  180: 'DB09079',
#  181: 'DB06626',
#  182: 'DB09078',
#  183: 'DB09371',
#  184: '2099',
#  185: 'DB00977',
#  186: 'DB00655',
#  187: 'DB01708',
#  188: 'DB00947',
#  189: 'DB00882',
#  190: 'DB00648',
#  191: 'DB01196',
#  192: 'DB01357',
#  193: 'DB00396',
#  194: 'DB00783',
#  195: 'DB06202',
#  196: 'DB00286',
#  197: 'DB00823',
#  198: 'DB06710',
#  199: 'DB01108',
#  200: 'DB00367',
#  201: 'DB11619',
#  202: 'DB01431',
#  203: 'DB00539',
#  204: 'DB04575',
#  205: 'DB01183',
#  206: 'DB00675',
#  207: 'DB00957',
#  208: 'DB04938',
#  209: 'estropipate',
#  210: 'DB01406',
#  211: 'DB00304',
#  212: 'DB01185',
#  213: 'DB06401',
#  214: 'DB13943',
#  215: 'DB09070',
#  216: 'DB01065',
#  217: 'DB00481',
#  218: 'DB00603',
#  219: 'DB00890',
#  220: 'DB00624',
#  221: 'DB00255',
#  222: 'DB13954',
#  223: '2260',
#  224: 'DB01109',
#  225: 'DB00039',
#  226: 'neridronic-acid',
#  227: '2224',
#  228: 'DB00884',
#  229: 'DB00630',
#  230: 'DB00282',
#  231: 'minodronic-acid',
#  232: 'DB00399',
#  233: 'DB00710',
#  234: 'DB00070',
#  235: '7040',
#  236: 'DB01034',
#  237: '2194',
#  238: 'DB01083',
#  239: 'DB00339',
#  240: 'DB09517',
#  241: '2512',
#  242: 'DB00893',
#  243: 'DB05099',
#  244: '2243',
#  245: 'DB00015',
#  246: 'DB00031',
#  247: 'DB11571',
#  248: 'DB11572',
#  249: 'DB00364',
#  250: 'DB00029',
#  251: 'DB00009',
#  252: 'DB00635',
#  253: '2908',
#  254: 'DB01234',
#  255: 'DB00663',
#  256: 'fludrocortisone-acetate',
#  257: 'DB00741',
#  258: 'DB01410',
#  259: 'DB00596',
#  260: 'DB00620',
#  261: 'megestrol-acetate',
#  262: 'DB00324',
#  263: 'DB00687',
#  264: 'DB00223',
#  265: 'dexamethasone-sodium-phosphate',
#  266: 'DB00443',
#  267: 'methylprednisolone-aceponate',
#  268: 'cortisone',
#  269: 'DB00860',
#  270: 'prednisolone-acetate',
#  271: 'fluocinolone-acetonide',
#  272: 'DB00873',
#  273: 'DB00588',
#  274: 'hydrocortisone-butyrate',
#  275: 'DB01260',
#  276: 'DB00896',
#  277: 'DB00547',
#  278: 'DB01380',
#  279: 'DB00838',
#  280: 'DB08867',
#  281: 'DB00288',
#  282: 'DB08906',
#  283: 'DB00351',
#  284: 'DB00764',
#  285: 'DB01013',
#  286: 'prednisolone-sodium-phosphate',
#  287: 'DB00180',
#  288: 'hydrocortisone-phosphate',
#  289: 'clobetasone-butyrate',
#  290: 'DB00591',
#  291: 'DB00240',
#  292: 'DB00834',
#  293: 'DB01047',
#  294: 'DB01222',
#  295: 'DB06786',
#  296: 'DB00959',
#  297: 'DB01130',
#  298: 'DB00253',
#  299: 'DB00394',
#  300: 'DB09091',
#  301: 'DB00846',
#  302: 'DB11824',
#  303: '5871',
#  304: 'DB00945',
#  305: '3309',
#  306: 'DB13999',
#  307: 'DB00025',
#  308: 'DB00428',
#  309: '6514',
#  310: 'DB00241',
#  311: '2898',
#  312: 'DB00849',
#  313: 'DB01352',
#  314: 'DB00237',
#  315: 'DB00306',
#  316: 'DB01353',
#  317: 'DB00794',
#  318: 'DB00599',
#  319: 'DB01174',
#  320: 'DB00418',
#  321: 'DB01351',
#  322: 'DB00312',
#  323: 'DB00142',
#  324: 'DB00273',
#  325: '2897',
#  326: '3984',
#  327: 'DB08912',
#  328: '3339',
#  329: 'DB00139',
#  330: '8974',
#  331: 'DB08818',
#  332: '708',
#  333: 'hyaluronic-acid',
#  334: 'DB00491',
#  335: '23193',
#  336: 'DB00188',
#  337: '5684',
#  338: 'DB08889',
#  339: '5747',
#  340: 'DB06372',
#  341: '3552',
#  342: 'thiram',
#  343: '3717',
#  344: 'DB08895',
#  345: 'DB11817',
#  346: 'DB08877',
#  347: '3856',
#  348: 'DB06756',
#  349: '596',
#  350: 'DB01367',
#  351: 'DB11581',
#  352: 'DB01229',
#  353: 'DB09401',
#  354: 'DB12243',
#  355: 'DB09213',
#  356: 'DB01248',
#  357: 'DB01050',
#  358: 'DB08871',
#  359: '8678',
#  360: '4790',
#  361: 'DB08814',
#  362: 'DB01411',
#  363: 'DB01041',
#  364: 'DB00244',
#  365: '240',
#  366: 'tepoxalin',
#  367: 'DB00586',
#  368: 'DB00744',
#  369: 'DB11994',
#  370: 'DB01014',
#  371: 'DB00233',
#  372: 'DB00795',
#  373: 'DB08955',
#  374: 'DB00179',
#  375: 'DB01017',
#  376: 'DB00939',
#  377: 'DB00163',
#  378: 'DB00471',
#  379: 'silibinin',
#  380: 'DB00514',
#  381: '4689',
#  382: 'DB00903',
#  383: '51176',
#  384: '5567',
#  385: '6622',
#  386: '5970',
#  387: 'DB08908',
#  388: 'DB06151',
#  389: '2353',
#  390: 'DB01592',
#  391: '2237',
#  392: '207',
#  393: 'arsenic-trioxide',
#  394: '2321',
#  395: 'DB09221',
#  396: 'DB09099',
#  397: '4985',
#  398: 'DB00956',
#  399: 'DB01192',
#  400: 'DB00318',
#  401: 'DB01081',
#  402: 'DB00327',
#  403: 'butorphanol-(+)-tartrate',
#  404: 'DB00295',
#  405: 'DB00193',
#  406: 'DB06204',
#  407: 'DB11130',
#  408: 'DB06230',
#  409: 'DB00844',
#  410: 'DB00813',
#  411: 'DB00704',
#  412: 'DB09289',
#  413: 'DB09272',
#  414: 'DB01452',
#  415: 'DB06800',
#  416: 'DB00921',
#  417: 'DB00647',
#  418: 'DB00497',
#  419: 'DB00854',
#  420: 'DB00836',
#  421: 'DB00611',
#  422: 'DB00806',
#  423: '5147',
#  424: 'DB00975',
#  425: 'DB00083',
#  426: '388',
#  427: 'DB00126',
#  428: '5066',
#  429: 'DB04519',
#  430: '5465',
#  431: 'DB00573',
#  432: 'DB01132',
#  433: 'DB01393',
#  434: 'DB01241',
#  435: 'DB00132',
#  436: 'DB01039',
#  437: 'DB00328',
#  438: 'DB08983',
#  439: 'DB00313',
#  440: 'DB09064',
#  441: 'DB03017',
#  442: 'DB00636',
#  443: 'DB00412',
#  444: 'DB13873',
#  445: 'DB00159',
#  446: 'DB09006',
#  447: '8503',
#  448: '5290',
#  449: 'DB12483',
#  450: 'DB09054',
#  451: 'DB00851',
#  452: '5226',
#  453: 'DB00920',
#  454: '6403',
#  455: 'DB00594',
#  456: '25865',
#  457: 'DB06637',
#  458: '3739',
#  459: '2241',
#  460: '5594',
#  461: '4751',
#  462: '5170',
#  463: 'DB00482',
#  464: '5590',
#  465: 'DB00307',
#  466: '6256',
#  467: 'DB00755',
#  468: 'DB00162',
#  469: 'DB00210',
#  470: 'DB01436',
#  471: 'DB00749',
#  472: '1191',
#  473: '7048',
#  474: '10572',
#  475: 'DB00864',
#  476: '2280',
#  477: 'DB00877',
#  478: 'zotarolimus',
#  479: 'DB00337',
#  480: '7046',
#  481: '472',
#  482: '25',
#  483: 'DB04868',
#  484: '4914',
#  485: '2242',
#  486: '6714',
#  487: '2048',
#  488: 'DB00922',
#  489: '7137',
#  490: 'DB01244',
#  491: 'DB00831',
#  492: '7157',
#  493: '5708',
#  494: '4921',
#  495: 'DB00108',
#  496: '3676',
#  497: 'DB09033',
#  498: 'DB00290',
#  499: '3980',
#  500: 'DB01349',
#  501: '186',
#  502: 'DB00796',
#  503: 'DB08822',
#  504: 'DB09121',
#  505: '5584',
#  506: '660',
#  507: 'DB09053',
#  508: '8573',
#  509: 'DB00798',
#  510: '4036',
#  511: 'gentamycin',
#  512: 'DB00013',
#  513: '2066',
#  514: 'DB03793',
#  515: '9367',
#  516: 'DB05016',
#  517: '1756',
#  518: 'DB00055',
#  519: '2157',
#  520: 'DB13933',
#  521: 'DB13152',
#  522: 'DB00100',
#  523: '5264',
#  524: 'L-Arginine',
#  525: '445',
#  526: 'DB00125',
#  527: 'DB00155',
#  528: 'DB00128',
#  529: 'L-Citrulline',
#  530: '5605',
#  531: 'DB08911',
#  532: 'DB00242',
#  533: '5422',
#  534: 'DB00987',
#  535: 'DB01280',
#  536: 'DB01073',
#  537: 'DB00631',
#  538: 'fludarabine-phosphate',
#  539: 'DB01238',
#  540: '3358',
#  541: 'DB00472',
#  542: 'spiperone',
#  543: 'DB00696',
#  544: 'DB00850',
#  545: 'DB00434',
#  546: 'DB00589',
#  547: 'DB01267',
#  548: 'DB00934',
#  549: 'DB00268',
#  550: 'DB06153',
#  551: 'DB00935',
#  552: 'DB00777',
#  553: 'DB01149',
#  554: 'DB00458',
#  555: 'DB00734',
#  556: 'DB00476',
#  557: 'DB00623',
#  558: 'DB00543',
#  559: 'DB06148',
#  560: 'DB04871',
#  561: 'DB00805',
#  562: 'DB00420',
#  563: 'DB01239',
#  564: 'DB09000',
#  565: 'DB00656',
#  566: 'DB06594',
#  567: 'DB01392',
#  568: 'DB00215',
#  569: 'DB01200',
#  570: 'DB01403',
#  571: 'DB01224',
#  572: 'DB01142',
#  573: 'DB08839',
#  574: 'DB01186',
#  575: 'DB09225',
#  576: 'DB00246',
#  577: 'DB01079',
#  578: 'DB12163',
#  579: 'DB00714',
#  580: 'DB01191',
#  581: 'DB09304',
#  582: 'DB00247',
#  583: 'DB06144',
#  584: 'DB01242',
#  585: 'DB00574',
#  586: 'DB09014',
#  587: 'DB00413',
#  588: 'DB00363',
#  589: 'DB00477',
#  590: 'DB06713',
#  591: '367',
#  592: 'DB00621',
#  593: 'DB01063',
#  594: 'DB01026',
#  595: 'DB01395',
#  596: 'DB09123',
#  597: 'DB06718',
#  598: 'DB08899',
#  599: 'DB00984',
#  600: 'DB00499',
#  601: 'testosterone-enanthate',
#  602: 'DB13169',
#  603: 'DB09389',
#  604: 'testosterone-undecanoate',
#  605: 'DB00665',
#  606: 'DB08804',
#  607: 'DB01128',
#  608: 'DB02901',
#  609: 'DB01420',
#  610: 'DB08604',
#  611: 'DB06412',
#  612: 'DB00858',
#  613: '7182',
#  614: '56924',
#  615: '598',
#  616: 'DB01599',
#  617: '19',
#  618: 'DB01016',
#  619: 'DB05266',
#  620: '5144',
#  621: 'DB05676',
#  622: 'DB00651',
#  623: 'DB00131',
#  624: 'DB09283',
#  625: 'DB01656',
#  626: 'DB01025',
#  627: 'DB09273',
#  628: 'DB00277',
#  629: 'DB01088',
#  630: '3172',
#  631: '3718',
#  632: '1432',
#  633: '5693',
#  634: '6278',
#  635: '3761',
#  636: '2047',
#  637: '50488',
#  638: 'DB01003',
#  639: '6286',
#  640: '659',
#  641: 'DB09039',
#  642: '7357',
#  643: 'DB00419',
#  644: '11157',
#  645: 'DB01138',
#  646: '1244',
#  647: '2185',
#  648: 'DB01097',
#  649: '2475',
#  650: 'DB06287',
#  651: 'DB01590',
#  652: '2100',
#  653: '5468',
#  654: 'DB09198',
#  655: 'DB00731',
#  656: 'DB01067',
#  657: 'DB01252',
#  658: 'DB00966',
#  659: 'DB00912',
#  660: '3312',
#  661: '5241',
#  662: 'DB00717',
#  663: 'DB05521',
#  664: 'chlormadinone-acetate',
#  665: 'DB00378',
#  666: 'DB00451',
#  667: '7068',
#  668: 'DB00509',
#  669: '5753',
#  670: '5689',
#  671: '6035',
#  672: '5880',
#  673: 'DB11324',
#  674: '7442',
#  675: 'DB09288',
#  676: 'DB01744',
#  677: 'DB00316',
#  678: 'DB06774',
#  679: 'DB11131',
#  680: 'DB04941',
#  681: '1080',
#  682: 'DB09280',
#  683: 'DB08820',
#  684: 'DB00887',
#  685: 'DB11712',
#  686: '190',
#  687: '4215',
#  688: '5607',
#  689: '9311',
#  690: 'sodium-salicylate',
#  691: 'DB03619',
#  692: '9971',
#  693: 'DB05990',
#  694: 'DB02659',
#  695: 'DB01586',
#  696: 'DB06777',
#  697: '5564',
#  698: 'DB00331',
#  699: '5571',
#  700: '51422',
#  701: '5565',
#  702: 'DB00928',
#  703: '1788',
#  704: 'DB01262',
#  705: '5602',
#  706: '5600',
#  707: 'DB06176',
#  708: '8841',
#  709: 'DB05015',
#  710: 'DB02546',
#  711: 'DB06603',
#  712: '5427',
#  713: '7099',
#  714: '4170',
#  715: 'DB04115',
#  716: '332',
#  717: 'DB00206',
#  718: '9212',
#  719: '8737',
#  720: 'DB00583',
#  721: '6583',
#  722: '116085',
#  723: 'DB11560',
#  724: 'DB01356',
#  725: '2932',
#  726: '94121',
#  727: '8576',
#  728: 'DB00141',
#  729: '55577',
#  730: 'DB01382',
#  731: '3758',
#  732: 'DB00222',
#  733: 'DB00839',
#  734: 'DB00414',
#  735: 'DB00350',
#  736: 'DB01124',
#  737: '5034',
#  738: 'DB01303',
#  739: '3066',
#  740: 'DB01223',
#  741: 'DB00227',
#  742: 'DB00608',
#  743: '54106',
#  744: 'DB01611',
#  745: '10188',
#  746: '5914',
#  747: 'DB00982',
#  748: 'DB04942',
#  749: 'DB00799',
#  750: '468',
#  751: '10499',
#  752: 'DB00157',
#  753: '4535',
#  754: '4502',
#  755: '5587',
#  756: 'DB00727',
#  757: '4881',
#  758: 'DB00325',
#  759: 'DB04899',
#  760: 'DB00883',
#  761: '4536',
#  762: '26251',
#  763: '3745',
#  764: 'DB08883',
#  765: '2890',
#  766: 'DB00228',
#  767: 'DB00606',
#  768: '9033',
#  769: '51086',
#  770: '9874',
#  771: '91754',
#  772: '5426',
#  773: '2030',
#  774: '81502',
#  775: '1459',
#  776: '4067',
#  777: '2261',
#  778: 'DB00627',
#  779: '23475',
#  780: 'DB01176',
#  781: '6783',
#  782: 'DB00133',
#  783: '875',
#  784: 'DB00114',
#  785: 'DB00151',
#  786: 'DB00118',
#  787: '8428',
#  788: 'DB00143',
#  789: '2947',
#  790: 'DB00720',
#  791: '293',
#  792: '8985',
#  793: '10016',
#  794: '95',
#  795: 'DB00811',
#  796: '22978',
#  797: '5682',
#  798: 'DB00173',
#  799: '6733',
#  800: '5152',
#  801: '10606',
#  802: '2571',
#  803: '1312',
#  804: 'DB00323',
#  805: 'DB11632',
#  806: 'DB00494',
#  807: 'DB00515',
#  808: '331',
#  809: '6548',
#  810: 'DB00768',
#  811: '6271',
#  812: '5515',
#  813: '7031',
#  814: '4707',
#  815: 'DB00145',
#  816: '27232',
#  817: 'DB00628',
#  818: '2563',
#  819: 'DB00842',
#  820: 'DB00801',
#  821: 'DB00690',
#  822: 'DB00404',
#  823: 'DB00292',
#  824: 'DB09118',
#  825: 'DB01558',
#  826: 'DB01588',
#  827: 'DB01107',
#  828: 'DB00349',
#  829: 'DB00463',
#  830: 'DB00546',
#  831: 'DB00189',
#  832: 'DB00475',
#  833: 'DB01215',
#  834: 'DB01956',
#  835: 'DB01589',
#  836: 'DB00186',
#  837: 'DB00371',
#  838: 'DB00897',
#  839: 'DB00683',
#  840: 'DB00829',
#  841: 'DB01595',
#  842: 'DB01437',
#  843: 'DB00659',
#  844: 'DB00818',
#  845: 'DB00402',
#  846: 'DB01068',
#  847: 'DB11582',
#  848: 'DB00231',
#  849: '113675',
#  850: '3728',
#  851: 'DB01698',
#  852: '8644',
#  853: 'DB00905',
#  854: '117144',
#  855: 'DB00770',
#  856: '6280',
#  857: '54107',
#  858: 'DB00819',
#  859: '358',
#  860: '5601',
#  861: '7376',
#  862: '6505',
#  863: '3507',
#  864: '5052',
#  865: '3091',
#  866: '1198',
#  867: '8767',
#  868: '1019',
#  869: '10733',
#  870: '4698',
#  871: '6616',
#  872: 'DB00130',
#  873: '2752',
#  874: '4140',
#  875: 'DB00148',
#  876: '1152',
#  877: '4715',
#  878: '4879',
#  879: '3853',
#  880: '4967',
#  881: '2203',
#  882: '6258',
#  883: '2495',
#  884: '2954',
#  885: '5585',
#  886: 'DB00993',
#  887: '3251',
#  888: 'DB01033',
#  889: '4723',
#  890: '23549',
#  891: '6257',
#  892: '55191',
#  893: '2653',
#  894: '64129',
#  895: '23564',
#  896: '2882',
#  897: '6820',
#  898: 'DB00607',
#  899: '9356',
#  900: 'DB01140',
#  901: 'DB01032',
#  902: 'DB01212',
#  903: 'DB01060',
#  904: 'DB00493',
#  905: '1196',
#  906: '6652',
#  907: '51327',
#  908: '1468',
#  909: '443',
#  910: 'cyclosporin-a',
#  911: '5530',
#  912: 'DB09220',
#  913: '10060',
#  914: '4792',
#  915: '9817',
#  916: '5478',
#  917: 'DB01110',
#  918: '56302',
#  919: '5159',
#  920: 'DB00102',
#  921: '4835',
#  922: 'DB00170',
#  923: '2580',
#  924: '58190',
#  925: '4145',
#  926: '4706',
#  927: '189',
#  928: '3779',
#  929: '1263',
#  930: '85007',
#  931: '7276',
#  932: '5973',
#  933: 'DB01394',
#  934: '7278',
#  935: 'DB00361',
#  936: 'DB04845',
#  937: '216',
#  938: '6273',
#  939: '635',
#  940: '6285',
#  941: '3612',
#  942: '6275',
#  943: '2941',
#  944: 'DB00063',
#  945: '3674',
#  946: 'DB00775',
#  947: 'DB00054',
#  948: 'DB00448',
#  949: '4137',
#  950: 'DB00637',
#  951: '2745',
#  952: '653361',
#  953: '5328',
#  954: '5054',
#  955: '2258',
#  956: 'DB00020',
#  957: '6383',
#  958: '5566',
#  959: 'bucladesine',
#  960: 'DB02701',
#  961: '142',
#  962: 'DB09074',
#  963: '3725',
#  964: 'DB00570',
#  965: 'DB01029',
#  966: '5423',
#  967: '2064',
#  968: '2065',
#  969: '5296',
#  970: '3326',
#  971: '5979',
#  972: '2044',
#  973: '3065',
#  974: 'DB08868',
#  975: 'DB06819',
#  976: '9759',
#  977: '10014',
#  978: '10013',
#  979: '1',
#  980: '23235',
#  981: '778',
#  982: '11011',
#  983: '9641',
#  984: '9475',
#  985: 'DB13165',
#  986: '5707',
#  987: '373156',
#  988: '5298',
#  989: '8780',
#  990: 'DB04865',
#  991: '6122',
#  992: '5198',
#  993: '673',
#  994: 'DB08881',
#  995: '8899',
#  996: 'DB00642',
#  997: '471',
#  998: 'DB00997',
#  999: '9221',
#  ...}

# %% [markdown]
# # Load saved diffusion profiles

# %%
dp_saved = DiffusionProfiles(alpha = None, max_iter = None, tol = None, weights = None, num_cores = None, save_load_file_path = "results/")

msi.load_saved_node_idx_mapping_and_nodelist(dp_saved.save_load_file_path)
dp_saved.load_diffusion_profiles(msi.drugs_in_graph + msi.indications_in_graph)

# %%
# Diffusion profile for Rosuvastatin (DB01098)
dp_saved.drug_or_indication2diffusion_profile["DB01098"]
# Out:
# array([6.88378645e-04, 3.78321317e-05, 2.92853909e-05, ...,
#        6.39679047e-06, 6.44090963e-06, 6.44090963e-06])

# %%
# Test against reference
test_diffusion_profiles("data/10_top_msi/", "results/")
